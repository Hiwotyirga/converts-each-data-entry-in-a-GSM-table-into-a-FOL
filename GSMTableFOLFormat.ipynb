# %%
import pandas
import GEOparse

# %%
gse = GEOparse.get_GEO(filepath=".\GSE34378_family.soft.gz")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\hiwot\AppData\Local\Temp\ipykernel_13040\1307441337.py:1: SyntaxWarning: invalid escape sequence '\G'
#   gse = GEOparse.get_GEO(filepath=".\GSE34378_family.soft.gz")
# 27-Mar-2025 16:45:37 INFO GEOparse - Parsing .\GSE34378_family.soft.gz:
# 27-Mar-2025 16:45:37 DEBUG GEOparse - DATABASE: GeoMiame
# 27-Mar-2025 16:45:37 DEBUG GEOparse - SERIES: GSE34378
# 27-Mar-2025 16:45:38 DEBUG GEOparse - PLATFORM: GPL14996
# 27-Mar-2025 16:45:38 DEBUG GEOparse - SAMPLE: GSM847777
# 27-Mar-2025 16:45:38 DEBUG GEOparse - SAMPLE: GSM847778
# 27-Mar-2025 16:45:38 DEBUG GEOparse - SAMPLE: GSM847779
# 27-Mar-2025 16:45:38 DEBUG GEOparse - SAMPLE: GSM847780
# 27-Mar-2025 16:45:38 DEBUG GEOparse - SAMPLE: GSM847781
# 27-Mar-2025 16:45:38 DEBUG GEOparse - SAMPLE: GSM847782
# 27-Mar-2025 16:45:38 DEBUG GEOparse - SAMPLE: GSM847783
# 27-Mar-2025 16:45:38 DEBUG GEOparse - SAMPLE: GSM847784
# 27-Mar-2025 16:45:39 DEBUG GEOparse - SAMPLE: GSM847785
# 27-Mar-2025 16:45:39 DEBUG GEOparse - SAMPLE: GSM847786
# 27-Mar-2025 16:45:39 DEBUG GEOparse - SAMPLE: GSM847787
# 27-Mar-2025 16:45:39 DEBUG GEOparse - SAMPLE: GSM847788
# 27-Mar-2025 16:45:39 DEBUG GEOparse - SAMPLE: GSM847789
# 27-Mar-2025 16:45:39 DEBUG GEOparse - SAMPLE: GSM847790
# 27-Mar-2025 16:45:39 DEBUG GEOparse - SAMPLE: GSM847791
# 27-Mar-2025 16:45:39 DEBUG GEOparse - SAMPLE: GSM847792
# 27-Mar-2025 16:45:39 DEBUG GEOparse - SAMPLE: GSM847793
# 27-Mar-2025 16:45:39 DEBUG GEOparse - SAMPLE: GSM847794
# 27-Mar-2025 16:45:40 DEBUG GEOparse - SAMPLE: GSM847795
# 27-Mar-2025 16:45:40 DEBUG GEOparse - SAMPLE: GSM847796
# 27-Mar-2025 16:45:40 DEBUG GEOparse - SAMPLE: GSM847797
# 27-Mar-2025 16:45:40 DEBUG GEOparse - SAMPLE: GSM847798
# 27-Mar-2025 16:45:40 DEBUG GEOparse - SAMPLE: GSM847799
# 27-Mar-2025 16:45:40 DEBUG GEOparse - SAMPLE: GSM847800
# 27-Mar-2025 16:45:40 DEBUG GEOparse - SAMPLE: GSM847801
# 27-Mar-2025 16:45:40 DEBUG GEOparse - SAMPLE: GSM847802
# 27-Mar-2025 16:45:41 DEBUG GEOparse - SAMPLE: GSM847803
# 27-Mar-2025 16:45:41 DEBUG GEOparse - SAMPLE: GSM847804
# 27-Mar-2025 16:45:41 DEBUG GEOparse - SAMPLE: GSM847805
# 27-Mar-2025 16:45:41 DEBUG GEOparse - SAMPLE: GSM847806
# 27-Mar-2025 16:45:41 DEBUG GEOparse - SAMPLE: GSM847807
# 27-Mar-2025 16:45:41 DEBUG GEOparse - SAMPLE: GSM847808
# 27-Mar-2025 16:45:41 DEBUG GEOparse - SAMPLE: GSM847809
# 27-Mar-2025 16:45:41 DEBUG GEOparse - SAMPLE: GSM847810
# 27-Mar-2025 16:45:41 DEBUG GEOparse - SAMPLE: GSM847811
# 27-Mar-2025 16:45:42 DEBUG GEOparse - SAMPLE: GSM847812
# 27-Mar-2025 16:45:42 DEBUG GEOparse - SAMPLE: GSM847813
# 27-Mar-2025 16:45:42 DEBUG GEOparse - SAMPLE: GSM847814
# 27-Mar-2025 16:45:42 DEBUG GEOparse - SAMPLE: GSM847815
# 27-Mar-2025 16:45:42 DEBUG GEOparse - SAMPLE: GSM847816
# 27-Mar-2025 16:45:42 DEBUG GEOparse - SAMPLE: GSM847817
# 27-Mar-2025 16:45:42 DEBUG GEOparse - SAMPLE: GSM847818
# 27-Mar-2025 16:45:42 DEBUG GEOparse - SAMPLE: GSM847819
# 27-Mar-2025 16:45:42 DEBUG GEOparse - SAMPLE: GSM847820
# 27-Mar-2025 16:45:43 DEBUG GEOparse - SAMPLE: GSM847821
# 27-Mar-2025 16:45:43 DEBUG GEOparse - SAMPLE: GSM847822
# 27-Mar-2025 16:45:43 DEBUG GEOparse - SAMPLE: GSM847823
# 27-Mar-2025 16:45:43 DEBUG GEOparse - SAMPLE: GSM847824
# 27-Mar-2025 16:45:43 DEBUG GEOparse - SAMPLE: GSM847825
# 27-Mar-2025 16:45:43 DEBUG GEOparse - SAMPLE: GSM847826
# 27-Mar-2025 16:45:43 DEBUG GEOparse - SAMPLE: GSM847827
# 27-Mar-2025 16:45:43 DEBUG GEOparse - SAMPLE: GSM847828
# 27-Mar-2025 16:45:43 DEBUG GEOparse - SAMPLE: GSM847829
# 27-Mar-2025 16:45:43 DEBUG GEOparse - SAMPLE: GSM847830
# 27-Mar-2025 16:45:44 DEBUG GEOparse - SAMPLE: GSM847831
# 27-Mar-2025 16:45:44 DEBUG GEOparse - SAMPLE: GSM847832
# 27-Mar-2025 16:45:44 DEBUG GEOparse - SAMPLE: GSM847833
# 27-Mar-2025 16:45:44 DEBUG GEOparse - SAMPLE: GSM847834
# 27-Mar-2025 16:45:44 DEBUG GEOparse - SAMPLE: GSM847835
# 27-Mar-2025 16:45:44 DEBUG GEOparse - SAMPLE: GSM847836
# 27-Mar-2025 16:45:44 DEBUG GEOparse - SAMPLE: GSM847837
# 27-Mar-2025 16:45:44 DEBUG GEOparse - SAMPLE: GSM847838
# 27-Mar-2025 16:45:44 DEBUG GEOparse - SAMPLE: GSM847839
# 27-Mar-2025 16:45:45 DEBUG GEOparse - SAMPLE: GSM847840
# 27-Mar-2025 16:45:45 DEBUG GEOparse - SAMPLE: GSM847841
# 27-Mar-2025 16:45:45 DEBUG GEOparse - SAMPLE: GSM847842
# 27-Mar-2025 16:45:45 DEBUG GEOparse - SAMPLE: GSM847843
# 27-Mar-2025 16:45:45 DEBUG GEOparse - SAMPLE: GSM847844
# 27-Mar-2025 16:45:45 DEBUG GEOparse - SAMPLE: GSM847845
# 27-Mar-2025 16:45:45 DEBUG GEOparse - SAMPLE: GSM847846
# 27-Mar-2025 16:45:45 DEBUG GEOparse - SAMPLE: GSM847847
# 27-Mar-2025 16:45:45 DEBUG GEOparse - SAMPLE: GSM847848
# 27-Mar-2025 16:45:45 DEBUG GEOparse - SAMPLE: GSM847849
# 27-Mar-2025 16:45:46 DEBUG GEOparse - SAMPLE: GSM847850
# 27-Mar-2025 16:45:46 DEBUG GEOparse - SAMPLE: GSM847851
# 27-Mar-2025 16:45:46 DEBUG GEOparse - SAMPLE: GSM847852
# 27-Mar-2025 16:45:46 DEBUG GEOparse - SAMPLE: GSM847853
# 27-Mar-2025 16:45:46 DEBUG GEOparse - SAMPLE: GSM847854
# 27-Mar-2025 16:45:46 DEBUG GEOparse - SAMPLE: GSM847855
# 27-Mar-2025 16:45:46 DEBUG GEOparse - SAMPLE: GSM847856
# 27-Mar-2025 16:45:46 DEBUG GEOparse - SAMPLE: GSM847857
# 27-Mar-2025 16:45:46 DEBUG GEOparse - SAMPLE: GSM847858
# 27-Mar-2025 16:45:47 DEBUG GEOparse - SAMPLE: GSM847859
# 27-Mar-2025 16:45:47 DEBUG GEOparse - SAMPLE: GSM847860
# 27-Mar-2025 16:45:47 DEBUG GEOparse - SAMPLE: GSM847861
# 27-Mar-2025 16:45:47 DEBUG GEOparse - SAMPLE: GSM847862
# 27-Mar-2025 16:45:47 DEBUG GEOparse - SAMPLE: GSM847863
# 27-Mar-2025 16:45:48 DEBUG GEOparse - SAMPLE: GSM847864
# 27-Mar-2025 16:45:48 DEBUG GEOparse - SAMPLE: GSM847865
# 27-Mar-2025 16:45:48 DEBUG GEOparse - SAMPLE: GSM847866

# %%
gsm_id = list(gse.gsms.keys())[0]

# %%
gsm = gse.gsms[gsm_id]

# %%
gsm.table.head(5)
# Out:
#           ID_REF     VALUE
# 0  100008567_atm  5.257324
# 1  100009600_atd  5.329803
# 2     100012_atd  2.811497
# 3     100017_atd  6.766313
# 4     100019_atd  7.192290

# %%
gsm.table.columns
# Out:
# Index(['ID_REF', 'VALUE'], dtype='object')

# %%
for key, value in gsm.metadata.items():
    print(f"{key}: {value[0]}")
# Out:
# title: kidney 13 wks rep 1
# geo_accession: GSM847777
# status: Public on Jul 10 2013
# submission_date: Dec 12 2011
# last_update_date: Jul 10 2013
# type: RNA
# channel_count: 1
# source_name_ch1: kidney 13 wks
# organism_ch1: Mus musculus
# taxid_ch1: 10090
# characteristics_ch1: tissue: kidney
# treatment_protocol_ch1: None
# growth_protocol_ch1: Female C57BL6/J mice were marked and randomized at the day of birth in different groups; i.e. longevity cohorts (previously described in Wijnhoven et al. (2005; DNA Repair (Amst) 4: 1314-1324.), or cross-sectional cohorts in which the mice were sacrificed at fixed time points. Cross-sectional cohorts C57BL6/J mice were sacrificed at a fixed age of 13, 26, 52, 78, 104 and 130 weeks. During the entire experiment, animals were kept in the same stringently controlled pathogen free (spf) environment, fed ad libitum and kept under a normal day/night rhythm. The microbiological status of the cohorts was monitored every 3 months.
# molecule_ch1: total RNA
# extract_protocol_ch1: Total RNA was isolated from liver, kidney, spleen, lung and brain, using the RNeasy Midi Kit (Qiagen, Valencia, CA, USA;). RNA quality was tested using automated gel electrophoresis (Bioanalyzer 2100; Agilent technologies, Amstelveen, the Netherlands). Only RIN > 7 were processed further.
# label_ch1: biotin
# label_protocol_ch1: In short, biotin-labeled cRNA samples were prepared as described in the Affymetrix expression analysis technical manual (Affymetrix) using 3 Î¼g of purified total RNA as template for the reaction. For this the One-Cycle cDNA Synthesis Kit (Affymetrix) was used.
# hyb_protocol: The labeled cDNA was hybridized to the Mouse GeneChip 430 2.0 (Affymetrix, Santa Clara, CA, USA). The GeneChip Hybridization, Wash and Stain Kit (Affymetrix, CA) was used for the hybridizations according to the protocol of the manufacturer.
# scan_protocol: GeneChips were scanned using the Affymetrix GCS3000 HR GeneChip Scanner and GCOS
# data_processing: The data were analyzed with the R statistical programming language (http://cran.r-project.org/) and the bioconductor affy package. The raw data were annotated according de Leeuw et al. (2008; BMC Res Notes. 19: 1-66 (hence the odd probeset identifiers)) and normalized using the robust multi-array average (RMA) algorithm (Irizarry et al., 2003; Biostatistics 4: 249-264). Please note that we corrected the data for labelling-batch effects in the paper.
# platform_id: GPL14996
# contact_name: Martijs,,Jonker
# contact_email: m.j.jonker@uva.nl
# contact_department: Microarray Department
# contact_institute: University of Amsterdam
# contact_address: Science Park 904
# contact_city: Amsterdam
# contact_zip/postal_code: 1090 GE
# contact_country: Netherlands
# supplementary_file: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM847nnn/GSM847777/suppl/GSM847777_IOP_001.CEL.gz
# series_id: GSE34378
# data_row_count: 35283

# %%
all_predicates = []


for key, value in gsm.metadata.items():
    metadata_value = value[0] if isinstance(value, (list, tuple)) else value
    clean_key = key.lower().replace(" ", "_").replace("/", "_")
    fol_predicate = f'has_{clean_key}("{gsm_id}", "{metadata_value}").'
    all_predicates.append(fol_predicate)

# %%
all_predicates
# Out:
# ['has_title("GSM847777", "kidney 13 wks rep 1").',
#  'has_geo_accession("GSM847777", "GSM847777").',
#  'has_status("GSM847777", "Public on Jul 10 2013").',
#  'has_submission_date("GSM847777", "Dec 12 2011").',
#  'has_last_update_date("GSM847777", "Jul 10 2013").',
#  'has_type("GSM847777", "RNA").',
#  'has_channel_count("GSM847777", "1").',
#  'has_source_name_ch1("GSM847777", "kidney 13 wks").',
#  'has_organism_ch1("GSM847777", "Mus musculus").',
#  'has_taxid_ch1("GSM847777", "10090").',
#  'has_characteristics_ch1("GSM847777", "tissue: kidney").',
#  'has_treatment_protocol_ch1("GSM847777", "None").',
#  'has_growth_protocol_ch1("GSM847777", "Female C57BL6/J mice were marked and randomized at the day of birth in different groups; i.e. longevity cohorts (previously described in Wijnhoven et al. (2005; DNA Repair (Amst) 4: 1314-1324.), or cross-sectional cohorts in which the mice were sacrificed at fixed time points. Cross-sectional cohorts C57BL6/J mice were sacrificed at a fixed age of 13, 26, 52, 78, 104 and 130 weeks. During the entire experiment, animals were kept in the same stringently controlled pathogen free (spf) environment, fed ad libitum and kept under a normal day/night rhythm. The microbiological status of the cohorts was monitored every 3 months.").',
#  'has_molecule_ch1("GSM847777", "total RNA").',
#  'has_extract_protocol_ch1("GSM847777", "Total RNA was isolated from liver, kidney, spleen, lung and brain, using the RNeasy Midi Kit (Qiagen, Valencia, CA, USA;). RNA quality was tested using automated gel electrophoresis (Bioanalyzer 2100; Agilent technologies, Amstelveen, the Netherlands). Only RIN > 7 were processed further.").',
#  'has_label_ch1("GSM847777", "biotin").',
#  'has_label_protocol_ch1("GSM847777", "In short, biotin-labeled cRNA samples were prepared as described in the Affymetrix expression analysis technical manual (Affymetrix) using 3 Î¼g of purified total RNA as template for the reaction. For this the One-Cycle cDNA Synthesis Kit (Affymetrix) was used.").',
#  'has_hyb_protocol("GSM847777", "The labeled cDNA was hybridized to the Mouse GeneChip 430 2.0 (Affymetrix, Santa Clara, CA, USA). The GeneChip Hybridization, Wash and Stain Kit (Affymetrix, CA) was used for the hybridizations according to the protocol of the manufacturer.").',
#  'has_scan_protocol("GSM847777", "GeneChips were scanned using the Affymetrix GCS3000 HR GeneChip Scanner and GCOS").',
#  'has_data_processing("GSM847777", "The data were analyzed with the R statistical programming language (http://cran.r-project.org/) and the bioconductor affy package. The raw data were annotated according de Leeuw et al. (2008; BMC Res Notes. 19: 1-66 (hence the odd probeset identifiers)) and normalized using the robust multi-array average (RMA) algorithm (Irizarry et al., 2003; Biostatistics 4: 249-264). Please note that we corrected the data for labelling-batch effects in the paper.").',
#  'has_platform_id("GSM847777", "GPL14996").',
#  'has_contact_name("GSM847777", "Martijs,,Jonker").',
#  'has_contact_email("GSM847777", "m.j.jonker@uva.nl").',
#  'has_contact_department("GSM847777", "Microarray Department").',
#  'has_contact_institute("GSM847777", "University of Amsterdam").',
#  'has_contact_address("GSM847777", "Science Park 904").',
#  'has_contact_city("GSM847777", "Amsterdam").',
#  'has_contact_zip_postal_code("GSM847777", "1090 GE").',
#  'has_contact_country("GSM847777", "Netherlands").',
#  'has_supplementary_file("GSM847777", "ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM847nnn/GSM847777/suppl/GSM847777_IOP_001.CEL.gz").',
#  'has_series_id("GSM847777", "GSE34378").',
#  'has_data_row_count("GSM847777", "35283").']

# %%
expression_predicates = []  

if hasattr(gsm, "table"):
    print("\nExpression Predicates:")
    df = gsm.table  
    
    for gene in df.index:  
        expr = df.loc[gene, "VALUE"] 
        try:
            expr_float = float(expr)
            expr_pred = f'expression_gene("{gsm_id}", "{gene}", {expr_float:.2f}).'
            expression_predicates.append(expr_pred)
            
            if expr_float > 5.0:
                high_pred = f'high_expression("{gsm_id}", "{gene}").'
                expression_predicates.append(high_pred)
                
            print(expr_pred)  
            if expr_float > 5.0:
                print(high_pred)
        except ValueError:
            continue
# Out:
# Expression Predicates:
# expression_gene("GSM847777", "0", 5.26).
# high_expression("GSM847777", "0").
# expression_gene("GSM847777", "1", 5.33).
# high_expression("GSM847777", "1").
# expression_gene("GSM847777", "2", 2.81).
# expression_gene("GSM847777", "3", 6.77).
# high_expression("GSM847777", "3").
# expression_gene("GSM847777", "4", 7.19).
# high_expression("GSM847777", "4").
# expression_gene("GSM847777", "5", 6.56).
# high_expression("GSM847777", "5").
# expression_gene("GSM847777", "6", 3.39).
# expression_gene("GSM847777", "7", 3.95).
# expression_gene("GSM847777", "8", 4.10).
# expression_gene("GSM847777", "9", 7.31).
# high_expression("GSM847777", "9").
# expression_gene("GSM847777", "10", 3.61).
# expression_gene("GSM847777", "11", 8.77).
# high_expression("GSM847777", "11").
# expression_gene("GSM847777", "12", 5.38).
# high_expression("GSM847777", "12").
# expression_gene("GSM847777", "13", 4.15).
# expression_gene("GSM847777", "14", 2.89).
# expression_gene("GSM847777", "15", 6.79).
# high_expression("GSM847777", "15").
# expression_gene("GSM847777", "16", 3.32).
# expression_gene("GSM847777", "17", 3.58).
# expression_gene("GSM847777", "18", 3.88).
# expression_gene("GSM847777", "19", 4.24).
# expression_gene("GSM847777", "20", 8.34).
# high_expression("GSM847777", "20").
# expression_gene("GSM847777", "21", 3.56).
# expression_gene("GSM847777", "22", 8.49).
# high_expression("GSM847777", "22").
# expression_gene("GSM847777", "23", 4.36).
# expression_gene("GSM847777", "24", 4.15).
# expression_gene("GSM847777", "25", 5.35).
# high_expression("GSM847777", "25").
# expression_gene("GSM847777", "26", 7.22).
# high_expression("GSM847777", "26").
# expression_gene("GSM847777", "27", 3.66).
# expression_gene("GSM847777", "28", 2.89).
# expression_gene("GSM847777", "29", 2.89).
# expression_gene("GSM847777", "30", 4.96).
# expression_gene("GSM847777", "31", 4.40).
# expression_gene("GSM847777", "32", 8.08).
# high_expression("GSM847777", "32").
# expression_gene("GSM847777", "33", 10.13).
# high_expression("GSM847777", "33").
# expression_gene("GSM847777", "34", 3.74).
# expression_gene("GSM847777", "35", 4.29).
# expression_gene("GSM847777", "36", 4.44).
# expression_gene("GSM847777", "37", 6.22).
# high_expression("GSM847777", "37").
# expression_gene("GSM847777", "38", 3.88).
# expression_gene("GSM847777", "39", 5.30).
# high_expression("GSM847777", "39").
# expression_gene("GSM847777", "40", 2.65).
# expression_gene("GSM847777", "41", 3.48).
# expression_gene("GSM847777", "42", 8.26).
# high_expression("GSM847777", "42").
# expression_gene("GSM847777", "43", 4.53).
# expression_gene("GSM847777", "44", 10.06).
# high_expression("GSM847777", "44").
# expression_gene("GSM847777", "45", 4.05).
# expression_gene("GSM847777", "46", 5.27).
# high_expression("GSM847777", "46").
# expression_gene("GSM847777", "47", 3.81).
# expression_gene("GSM847777", "48", 8.50).
# high_expression("GSM847777", "48").
# expression_gene("GSM847777", "49", 8.70).
# high_expression("GSM847777", "49").
# expression_gene("GSM847777", "50", 4.39).
# expression_gene("GSM847777", "51", 5.01).
# high_expression("GSM847777", "51").
# expression_gene("GSM847777", "52", 3.73).
# expression_gene("GSM847777", "53", 3.34).
# expression_gene("GSM847777", "54", 4.65).
# expression_gene("GSM847777", "55", 3.83).
# expression_gene("GSM847777", "56", 4.43).
# expression_gene("GSM847777", "57", 3.17).
# expression_gene("GSM847777", "58", 3.87).
# expression_gene("GSM847777", "59", 3.86).
# expression_gene("GSM847777", "60", 3.39).
# expression_gene("GSM847777", "61", 4.54).
# expression_gene("GSM847777", "62", 3.71).
# expression_gene("GSM847777", "63", 4.88).
# expression_gene("GSM847777", "64", 4.39).
# expression_gene("GSM847777", "65", 4.18).
# expression_gene("GSM847777", "66", 4.08).
# expression_gene("GSM847777", "67", 3.47).
# expression_gene("GSM847777", "68", 3.93).
# expression_gene("GSM847777", "69", 4.81).
# expression_gene("GSM847777", "70", 9.63).
# high_expression("GSM847777", "70").
# expression_gene("GSM847777", "71", 4.10).
# expression_gene("GSM847777", "72", 5.51).
# high_expression("GSM847777", "72").
# expression_gene("GSM847777", "73", 4.15).
# expression_gene("GSM847777", "74", 11.34).
# high_expression("GSM847777", "74").
# expression_gene("GSM847777", "75", 5.06).
# high_expression("GSM847777", "75").
# expression_gene("GSM847777", "76", 7.30).
# high_expression("GSM847777", "76").
# expression_gene("GSM847777", "77", 3.24).
# expression_gene("GSM847777", "78", 3.47).
# expression_gene("GSM847777", "79", 5.24).
# high_expression("GSM847777", "79").
# expression_gene("GSM847777", "80", 5.18).
# high_expression("GSM847777", "80").
# expression_gene("GSM847777", "81", 3.65).
# expression_gene("GSM847777", "82", 4.22).
# expression_gene("GSM847777", "83", 5.02).
# high_expression("GSM847777", "83").
# expression_gene("GSM847777", "84", 2.66).
# expression_gene("GSM847777", "85", 6.45).
# high_expression("GSM847777", "85").
# expression_gene("GSM847777", "86", 5.21).
# high_expression("GSM847777", "86").
# expression_gene("GSM847777", "87", 3.23).
# expression_gene("GSM847777", "88", 4.12).
# expression_gene("GSM847777", "89", 6.45).
# high_expression("GSM847777", "89").
# expression_gene("GSM847777", "90", 3.27).
# expression_gene("GSM847777", "91", 6.82).
# high_expression("GSM847777", "91").
# expression_gene("GSM847777", "92", 6.52).
# high_expression("GSM847777", "92").
# expression_gene("GSM847777", "93", 4.86).
# expression_gene("GSM847777", "94", 5.49).
# high_expression("GSM847777", "94").
# expression_gene("GSM847777", "95", 5.93).
# high_expression("GSM847777", "95").
# expression_gene("GSM847777", "96", 3.97).
# expression_gene("GSM847777", "97", 6.57).
# high_expression("GSM847777", "97").
# expression_gene("GSM847777", "98", 3.43).
# expression_gene("GSM847777", "99", 6.80).
# high_expression("GSM847777", "99").
# expression_gene("GSM847777", "100", 6.96).
# high_expression("GSM847777", "100").
# expression_gene("GSM847777", "101", 7.76).
# high_expression("GSM847777", "101").
# expression_gene("GSM847777", "102", 2.53).
# expression_gene("GSM847777", "103", 4.77).
# expression_gene("GSM847777", "104", 7.77).
# high_expression("GSM847777", "104").
# expression_gene("GSM847777", "105", 7.28).
# high_expression("GSM847777", "105").
# expression_gene("GSM847777", "106", 6.99).
# high_expression("GSM847777", "106").
# expression_gene("GSM847777", "107", 3.31).
# expression_gene("GSM847777", "108", 2.91).
# expression_gene("GSM847777", "109", 3.37).
# expression_gene("GSM847777", "110", 6.85).
# high_expression("GSM847777", "110").
# expression_gene("GSM847777", "111", 4.23).
# expression_gene("GSM847777", "112", 2.87).
# expression_gene("GSM847777", "113", 9.89).
# high_expression("GSM847777", "113").
# expression_gene("GSM847777", "114", 3.16).
# expression_gene("GSM847777", "115", 4.32).
# expression_gene("GSM847777", "116", 11.72).
# high_expression("GSM847777", "116").
# expression_gene("GSM847777", "117", 2.76).
# expression_gene("GSM847777", "118", 5.99).
# high_expression("GSM847777", "118").
# expression_gene("GSM847777", "119", 4.76).
# expression_gene("GSM847777", "120", 3.00).
# expression_gene("GSM847777", "121", 5.87).
# high_expression("GSM847777", "121").
# expression_gene("GSM847777", "122", 3.57).
# expression_gene("GSM847777", "123", 5.28).
# high_expression("GSM847777", "123").
# expression_gene("GSM847777", "124", 4.01).
# expression_gene("GSM847777", "125", 5.91).
# high_expression("GSM847777", "125").
# expression_gene("GSM847777", "126", 4.08).
# expression_gene("GSM847777", "127", 3.38).
# expression_gene("GSM847777", "128", 3.18).
# expression_gene("GSM847777", "129", 4.65).
# expression_gene("GSM847777", "130", 3.15).
# expression_gene("GSM847777", "131", 5.19).
# high_expression("GSM847777", "131").
# expression_gene("GSM847777", "132", 5.76).
# high_expression("GSM847777", "132").
# expression_gene("GSM847777", "133", 5.80).
# high_expression("GSM847777", "133").
# expression_gene("GSM847777", "134", 3.37).
# expression_gene("GSM847777", "135", 3.03).
# expression_gene("GSM847777", "136", 5.37).
# high_expression("GSM847777", "136").
# expression_gene("GSM847777", "137", 4.16).
# expression_gene("GSM847777", "138", 4.73).
# expression_gene("GSM847777", "139", 7.32).
# high_expression("GSM847777", "139").
# expression_gene("GSM847777", "140", 3.97).
# expression_gene("GSM847777", "141", 4.27).
# expression_gene("GSM847777", "142", 6.02).
# high_expression("GSM847777", "142").
# expression_gene("GSM847777", "143", 4.65).
# expression_gene("GSM847777", "144", 4.40).
# expression_gene("GSM847777", "145", 6.86).
# high_expression("GSM847777", "145").
# expression_gene("GSM847777", "146", 2.92).
# expression_gene("GSM847777", "147", 8.86).
# high_expression("GSM847777", "147").
# expression_gene("GSM847777", "148", 3.40).
# expression_gene("GSM847777", "149", 4.38).
# expression_gene("GSM847777", "150", 4.09).
# expression_gene("GSM847777", "151", 3.61).
# expression_gene("GSM847777", "152", 3.60).
# expression_gene("GSM847777", "153", 5.47).
# high_expression("GSM847777", "153").
# expression_gene("GSM847777", "154", 2.91).
# expression_gene("GSM847777", "155", 3.44).
# expression_gene("GSM847777", "156", 4.33).
# expression_gene("GSM847777", "157", 3.48).
# expression_gene("GSM847777", "158", 3.91).
# expression_gene("GSM847777", "159", 6.57).
# high_expression("GSM847777", "159").
# expression_gene("GSM847777", "160", 5.35).
# high_expression("GSM847777", "160").
# expression_gene("GSM847777", "161", 5.61).
# high_expression("GSM847777", "161").
# expression_gene("GSM847777", "162", 3.11).
# expression_gene("GSM847777", "163", 5.28).
# high_expression("GSM847777", "163").
# expression_gene("GSM847777", "164", 5.28).
# high_expression("GSM847777", "164").
# expression_gene("GSM847777", "165", 4.54).
# expression_gene("GSM847777", "166", 4.81).
# expression_gene("GSM847777", "167", 3.99).
# expression_gene("GSM847777", "168", 2.83).
# expression_gene("GSM847777", "169", 4.48).
# expression_gene("GSM847777", "170", 12.90).
# high_expression("GSM847777", "170").
# expression_gene("GSM847777", "171", 5.56).
# high_expression("GSM847777", "171").
# expression_gene("GSM847777", "172", 9.68).
# high_expression("GSM847777", "172").
# expression_gene("GSM847777", "173", 3.15).
# expression_gene("GSM847777", "174", 3.24).
# expression_gene("GSM847777", "175", 3.71).
# expression_gene("GSM847777", "176", 5.58).
# high_expression("GSM847777", "176").
# expression_gene("GSM847777", "177", 3.71).
# expression_gene("GSM847777", "178", 7.00).
# high_expression("GSM847777", "178").
# expression_gene("GSM847777", "179", 10.86).
# high_expression("GSM847777", "179").
# expression_gene("GSM847777", "180", 4.68).
# expression_gene("GSM847777", "181", 6.02).
# high_expression("GSM847777", "181").
# expression_gene("GSM847777", "182", 3.07).
# expression_gene("GSM847777", "183", 4.48).
# expression_gene("GSM847777", "184", 4.59).
# expression_gene("GSM847777", "185", 4.83).
# expression_gene("GSM847777", "186", 3.62).
# expression_gene("GSM847777", "187", 2.69).
# expression_gene("GSM847777", "188", 3.33).
# expression_gene("GSM847777", "189", 5.79).
# high_expression("GSM847777", "189").
# expression_gene("GSM847777", "190", 3.43).
# expression_gene("GSM847777", "191", 3.23).
# expression_gene("GSM847777", "192", 3.24).
# expression_gene("GSM847777", "193", 4.53).
# expression_gene("GSM847777", "194", 5.41).
# high_expression("GSM847777", "194").
# expression_gene("GSM847777", "195", 7.01).
# high_expression("GSM847777", "195").
# expression_gene("GSM847777", "196", 3.27).
# expression_gene("GSM847777", "197", 2.96).
# expression_gene("GSM847777", "198", 4.75).
# expression_gene("GSM847777", "199", 6.01).
# high_expression("GSM847777", "199").
# expression_gene("GSM847777", "200", 5.13).
# high_expression("GSM847777", "200").
# expression_gene("GSM847777", "201", 3.63).
# expression_gene("GSM847777", "202", 3.46).
# expression_gene("GSM847777", "203", 3.75).
# expression_gene("GSM847777", "204", 6.39).
# high_expression("GSM847777", "204").
# expression_gene("GSM847777", "205", 3.56).
# expression_gene("GSM847777", "206", 5.44).
# high_expression("GSM847777", "206").
# expression_gene("GSM847777", "207", 5.82).
# high_expression("GSM847777", "207").
# expression_gene("GSM847777", "208", 4.39).
# expression_gene("GSM847777", "209", 6.63).
# high_expression("GSM847777", "209").
# expression_gene("GSM847777", "210", 8.07).
# high_expression("GSM847777", "210").
# expression_gene("GSM847777", "211", 5.36).
# high_expression("GSM847777", "211").
# expression_gene("GSM847777", "212", 8.96).
# high_expression("GSM847777", "212").
# expression_gene("GSM847777", "213", 2.75).
# expression_gene("GSM847777", "214", 4.97).
# expression_gene("GSM847777", "215", 5.20).
# high_expression("GSM847777", "215").
# expression_gene("GSM847777", "216", 3.11).
# expression_gene("GSM847777", "217", 6.68).
# high_expression("GSM847777", "217").
# expression_gene("GSM847777", "218", 7.55).
# high_expression("GSM847777", "218").
# expression_gene("GSM847777", "219", 2.94).
# expression_gene("GSM847777", "220", 6.12).
# high_expression("GSM847777", "220").
# expression_gene("GSM847777", "221", 3.18).
# expression_gene("GSM847777", "222", 4.35).
# expression_gene("GSM847777", "223", 3.03).
# expression_gene("GSM847777", "224", 3.03).
# expression_gene("GSM847777", "225", 3.70).
# expression_gene("GSM847777", "226", 3.35).
# expression_gene("GSM847777", "227", 5.84).
# high_expression("GSM847777", "227").
# expression_gene("GSM847777", "228", 4.57).
# expression_gene("GSM847777", "229", 6.49).
# high_expression("GSM847777", "229").
# expression_gene("GSM847777", "230", 2.67).
# expression_gene("GSM847777", "231", 3.18).
# expression_gene("GSM847777", "232", 5.46).
# high_expression("GSM847777", "232").
# expression_gene("GSM847777", "233", 3.46).
# expression_gene("GSM847777", "234", 4.77).
# expression_gene("GSM847777", "235", 6.30).
# high_expression("GSM847777", "235").
# expression_gene("GSM847777", "236", 4.04).
# expression_gene("GSM847777", "237", 3.52).
# expression_gene("GSM847777", "238", 4.28).
# expression_gene("GSM847777", "239", 3.64).
# expression_gene("GSM847777", "240", 2.87).
# expression_gene("GSM847777", "241", 3.30).
# expression_gene("GSM847777", "242", 6.44).
# high_expression("GSM847777", "242").
# expression_gene("GSM847777", "243", 3.21).
# expression_gene("GSM847777", "244", 4.51).
# expression_gene("GSM847777", "245", 5.36).
# high_expression("GSM847777", "245").
# expression_gene("GSM847777", "246", 4.20).
# expression_gene("GSM847777", "247", 5.81).
# high_expression("GSM847777", "247").
# expression_gene("GSM847777", "248", 7.19).
# high_expression("GSM847777", "248").
# expression_gene("GSM847777", "249", 3.66).
# expression_gene("GSM847777", "250", 2.91).
# expression_gene("GSM847777", "251", 5.40).
# high_expression("GSM847777", "251").
# expression_gene("GSM847777", "252", 8.14).
# high_expression("GSM847777", "252").
# expression_gene("GSM847777", "253", 3.78).
# expression_gene("GSM847777", "254", 8.51).
# high_expression("GSM847777", "254").
# expression_gene("GSM847777", "255", 5.08).
# high_expression("GSM847777", "255").
# expression_gene("GSM847777", "256", 4.74).
# expression_gene("GSM847777", "257", 4.29).
# expression_gene("GSM847777", "258", 4.31).
# expression_gene("GSM847777", "259", 3.72).
# expression_gene("GSM847777", "260", 6.11).
# high_expression("GSM847777", "260").
# expression_gene("GSM847777", "261", 3.00).
# expression_gene("GSM847777", "262", 4.41).
# expression_gene("GSM847777", "263", 3.89).
# expression_gene("GSM847777", "264", 3.91).
# expression_gene("GSM847777", "265", 4.81).
# expression_gene("GSM847777", "266", 9.05).
# high_expression("GSM847777", "266").
# expression_gene("GSM847777", "267", 3.70).
# expression_gene("GSM847777", "268", 3.04).
# expression_gene("GSM847777", "269", 5.15).
# high_expression("GSM847777", "269").
# expression_gene("GSM847777", "270", 3.81).
# expression_gene("GSM847777", "271", 5.31).
# high_expression("GSM847777", "271").
# expression_gene("GSM847777", "272", 4.73).
# expression_gene("GSM847777", "273", 6.50).
# high_expression("GSM847777", "273").
# expression_gene("GSM847777", "274", 6.71).
# high_expression("GSM847777", "274").
# expression_gene("GSM847777", "275", 6.32).
# high_expression("GSM847777", "275").
# expression_gene("GSM847777", "276", 3.92).
# expression_gene("GSM847777", "277", 4.01).
# expression_gene("GSM847777", "278", 3.51).
# expression_gene("GSM847777", "279", 4.25).
# expression_gene("GSM847777", "280", 4.42).
# expression_gene("GSM847777", "281", 7.89).
# high_expression("GSM847777", "281").
# expression_gene("GSM847777", "282", 3.63).
# expression_gene("GSM847777", "283", 7.77).
# high_expression("GSM847777", "283").
# expression_gene("GSM847777", "284", 3.35).
# expression_gene("GSM847777", "285", 4.49).
# expression_gene("GSM847777", "286", 3.52).
# expression_gene("GSM847777", "287", 3.86).
# expression_gene("GSM847777", "288", 4.36).
# expression_gene("GSM847777", "289", 4.15).
# expression_gene("GSM847777", "290", 3.40).
# expression_gene("GSM847777", "291", 5.44).
# high_expression("GSM847777", "291").
# expression_gene("GSM847777", "292", 5.12).
# high_expression("GSM847777", "292").
# expression_gene("GSM847777", "293", 6.28).
# high_expression("GSM847777", "293").
# expression_gene("GSM847777", "294", 4.49).
# expression_gene("GSM847777", "295", 10.44).
# high_expression("GSM847777", "295").
# expression_gene("GSM847777", "296", 10.81).
# high_expression("GSM847777", "296").
# expression_gene("GSM847777", "297", 5.57).
# high_expression("GSM847777", "297").
# expression_gene("GSM847777", "298", 7.94).
# high_expression("GSM847777", "298").
# expression_gene("GSM847777", "299", 7.17).
# high_expression("GSM847777", "299").
# expression_gene("GSM847777", "300", 5.89).
# high_expression("GSM847777", "300").
# expression_gene("GSM847777", "301", 4.25).
# expression_gene("GSM847777", "302", 4.41).
# expression_gene("GSM847777", "303", 3.42).
# expression_gene("GSM847777", "304", 5.79).
# high_expression("GSM847777", "304").
# expression_gene("GSM847777", "305", 5.22).
# high_expression("GSM847777", "305").
# expression_gene("GSM847777", "306", 8.31).
# high_expression("GSM847777", "306").
# expression_gene("GSM847777", "307", 6.71).
# high_expression("GSM847777", "307").
# expression_gene("GSM847777", "308", 3.71).
# expression_gene("GSM847777", "309", 4.42).
# expression_gene("GSM847777", "310", 5.71).
# high_expression("GSM847777", "310").
# expression_gene("GSM847777", "311", 5.18).
# high_expression("GSM847777", "311").
# expression_gene("GSM847777", "312", 3.73).
# expression_gene("GSM847777", "313", 6.82).
# high_expression("GSM847777", "313").
# expression_gene("GSM847777", "314", 4.18).
# expression_gene("GSM847777", "315", 4.29).
# expression_gene("GSM847777", "316", 3.64).
# expression_gene("GSM847777", "317", 3.92).
# expression_gene("GSM847777", "318", 5.05).
# high_expression("GSM847777", "318").
# expression_gene("GSM847777", "319", 4.63).
# expression_gene("GSM847777", "320", 5.42).
# high_expression("GSM847777", "320").
# expression_gene("GSM847777", "321", 5.84).
# high_expression("GSM847777", "321").
# expression_gene("GSM847777", "322", 5.53).
# high_expression("GSM847777", "322").
# expression_gene("GSM847777", "323", 3.49).
# expression_gene("GSM847777", "324", 5.01).
# high_expression("GSM847777", "324").
# expression_gene("GSM847777", "325", 3.72).
# expression_gene("GSM847777", "326", 10.30).
# high_expression("GSM847777", "326").
# expression_gene("GSM847777", "327", 3.41).
# expression_gene("GSM847777", "328", 8.56).
# high_expression("GSM847777", "328").
# expression_gene("GSM847777", "329", 7.34).
# high_expression("GSM847777", "329").
# expression_gene("GSM847777", "330", 5.30).
# high_expression("GSM847777", "330").
# expression_gene("GSM847777", "331", 10.02).
# high_expression("GSM847777", "331").
# expression_gene("GSM847777", "332", 10.46).
# high_expression("GSM847777", "332").
# expression_gene("GSM847777", "333", 6.53).
# high_expression("GSM847777", "333").
# expression_gene("GSM847777", "334", 7.14).
# high_expression("GSM847777", "334").
# expression_gene("GSM847777", "335", 7.38).
# high_expression("GSM847777", "335").
# expression_gene("GSM847777", "336", 3.37).
# expression_gene("GSM847777", "337", 3.69).
# expression_gene("GSM847777", "338", 9.25).
# high_expression("GSM847777", "338").
# expression_gene("GSM847777", "339", 3.66).
# expression_gene("GSM847777", "340", 10.81).
# high_expression("GSM847777", "340").
# expression_gene("GSM847777", "341", 2.99).
# expression_gene("GSM847777", "342", 3.09).
# expression_gene("GSM847777", "343", 2.87).
# expression_gene("GSM847777", "344", 2.85).
# expression_gene("GSM847777", "345", 3.51).
# expression_gene("GSM847777", "346", 7.97).
# high_expression("GSM847777", "346").
# expression_gene("GSM847777", "347", 4.71).
# expression_gene("GSM847777", "348", 8.11).
# high_expression("GSM847777", "348").
# expression_gene("GSM847777", "349", 5.02).
# high_expression("GSM847777", "349").
# expression_gene("GSM847777", "350", 4.17).
# expression_gene("GSM847777", "351", 3.67).
# expression_gene("GSM847777", "352", 7.99).
# high_expression("GSM847777", "352").
# expression_gene("GSM847777", "353", 6.78).
# high_expression("GSM847777", "353").
# expression_gene("GSM847777", "354", 5.27).
# high_expression("GSM847777", "354").
# expression_gene("GSM847777", "355", 7.20).
# high_expression("GSM847777", "355").
# expression_gene("GSM847777", "356", 5.76).
# high_expression("GSM847777", "356").
# expression_gene("GSM847777", "357", 3.06).
# expression_gene("GSM847777", "358", 3.26).
# expression_gene("GSM847777", "359", 6.85).
# high_expression("GSM847777", "359").
# expression_gene("GSM847777", "360", 5.22).
# high_expression("GSM847777", "360").
# expression_gene("GSM847777", "361", 5.10).
# high_expression("GSM847777", "361").
# expression_gene("GSM847777", "362", 3.95).
# expression_gene("GSM847777", "363", 3.27).
# expression_gene("GSM847777", "364", 7.41).
# high_expression("GSM847777", "364").
# expression_gene("GSM847777", "365", 3.13).
# expression_gene("GSM847777", "366", 3.44).
# expression_gene("GSM847777", "367", 10.93).
# high_expression("GSM847777", "367").
# expression_gene("GSM847777", "368", 6.93).
# high_expression("GSM847777", "368").
# expression_gene("GSM847777", "369", 4.80).
# expression_gene("GSM847777", "370", 6.94).
# high_expression("GSM847777", "370").
# expression_gene("GSM847777", "371", 6.78).
# high_expression("GSM847777", "371").
# expression_gene("GSM847777", "372", 7.53).
# high_expression("GSM847777", "372").
# expression_gene("GSM847777", "373", 6.21).
# high_expression("GSM847777", "373").
# expression_gene("GSM847777", "374", 4.72).
# expression_gene("GSM847777", "375", 5.67).
# high_expression("GSM847777", "375").
# expression_gene("GSM847777", "376", 5.95).
# high_expression("GSM847777", "376").
# expression_gene("GSM847777", "377", 6.79).
# high_expression("GSM847777", "377").
# expression_gene("GSM847777", "378", 7.03).
# high_expression("GSM847777", "378").
# expression_gene("GSM847777", "379", 7.78).
# high_expression("GSM847777", "379").
# expression_gene("GSM847777", "380", 8.21).
# high_expression("GSM847777", "380").
# expression_gene("GSM847777", "381", 5.31).
# high_expression("GSM847777", "381").
# expression_gene("GSM847777", "382", 5.35).
# high_expression("GSM847777", "382").
# expression_gene("GSM847777", "383", 3.88).
# expression_gene("GSM847777", "384", 6.54).
# high_expression("GSM847777", "384").
# expression_gene("GSM847777", "385", 6.77).
# high_expression("GSM847777", "385").
# expression_gene("GSM847777", "386", 8.85).
# high_expression("GSM847777", "386").
# expression_gene("GSM847777", "387", 7.31).
# high_expression("GSM847777", "387").
# expression_gene("GSM847777", "388", 7.65).
# high_expression("GSM847777", "388").
# expression_gene("GSM847777", "389", 4.90).
# expression_gene("GSM847777", "390", 7.24).
# high_expression("GSM847777", "390").
# expression_gene("GSM847777", "391", 7.46).
# high_expression("GSM847777", "391").
# expression_gene("GSM847777", "392", 7.42).
# high_expression("GSM847777", "392").
# expression_gene("GSM847777", "393", 4.46).
# expression_gene("GSM847777", "394", 3.23).
# expression_gene("GSM847777", "395", 6.07).
# high_expression("GSM847777", "395").
# expression_gene("GSM847777", "396", 2.95).
# expression_gene("GSM847777", "397", 5.83).
# high_expression("GSM847777", "397").
# expression_gene("GSM847777", "398", 2.80).
# expression_gene("GSM847777", "399", 2.54).
# expression_gene("GSM847777", "400", 6.13).
# high_expression("GSM847777", "400").
# expression_gene("GSM847777", "401", 8.71).
# high_expression("GSM847777", "401").
# expression_gene("GSM847777", "402", 6.78).
# high_expression("GSM847777", "402").
# expression_gene("GSM847777", "403", 6.05).
# high_expression("GSM847777", "403").
# expression_gene("GSM847777", "404", 3.49).
# expression_gene("GSM847777", "405", 6.72).
# high_expression("GSM847777", "405").
# expression_gene("GSM847777", "406", 8.78).
# high_expression("GSM847777", "406").
# expression_gene("GSM847777", "407", 4.88).
# expression_gene("GSM847777", "408", 6.02).
# high_expression("GSM847777", "408").
# expression_gene("GSM847777", "409", 6.11).
# high_expression("GSM847777", "409").
# expression_gene("GSM847777", "410", 4.52).
# expression_gene("GSM847777", "411", 4.67).
# expression_gene("GSM847777", "412", 6.20).
# high_expression("GSM847777", "412").
# expression_gene("GSM847777", "413", 7.36).
# high_expression("GSM847777", "413").
# expression_gene("GSM847777", "414", 7.90).
# high_expression("GSM847777", "414").
# expression_gene("GSM847777", "415", 6.59).
# high_expression("GSM847777", "415").
# expression_gene("GSM847777", "416", 6.44).
# high_expression("GSM847777", "416").
# expression_gene("GSM847777", "417", 7.53).
# high_expression("GSM847777", "417").
# expression_gene("GSM847777", "418", 6.72).
# high_expression("GSM847777", "418").
# expression_gene("GSM847777", "419", 6.70).
# high_expression("GSM847777", "419").
# expression_gene("GSM847777", "420", 3.87).
# expression_gene("GSM847777", "421", 5.57).
# high_expression("GSM847777", "421").
# expression_gene("GSM847777", "422", 6.66).
# high_expression("GSM847777", "422").
# expression_gene("GSM847777", "423", 7.70).
# high_expression("GSM847777", "423").
# expression_gene("GSM847777", "424", 7.15).
# high_expression("GSM847777", "424").
# expression_gene("GSM847777", "425", 3.23).
# expression_gene("GSM847777", "426", 3.97).
# expression_gene("GSM847777", "427", 7.24).
# high_expression("GSM847777", "427").
# expression_gene("GSM847777", "428", 2.99).
# expression_gene("GSM847777", "429", 3.05).
# expression_gene("GSM847777", "430", 2.93).
# expression_gene("GSM847777", "431", 3.01).
# expression_gene("GSM847777", "432", 3.59).
# expression_gene("GSM847777", "433", 4.41).
# expression_gene("GSM847777", "434", 9.83).
# high_expression("GSM847777", "434").
# expression_gene("GSM847777", "435", 5.25).
# high_expression("GSM847777", "435").
# expression_gene("GSM847777", "436", 7.64).
# high_expression("GSM847777", "436").
# expression_gene("GSM847777", "437", 5.88).
# high_expression("GSM847777", "437").
# expression_gene("GSM847777", "438", 5.30).
# high_expression("GSM847777", "438").
# expression_gene("GSM847777", "439", 6.19).
# high_expression("GSM847777", "439").
# expression_gene("GSM847777", "440", 4.46).
# expression_gene("GSM847777", "441", 8.23).
# high_expression("GSM847777", "441").
# expression_gene("GSM847777", "442", 2.99).
# expression_gene("GSM847777", "443", 8.03).
# high_expression("GSM847777", "443").
# expression_gene("GSM847777", "444", 2.70).
# expression_gene("GSM847777", "445", 4.62).
# expression_gene("GSM847777", "446", 7.35).
# high_expression("GSM847777", "446").
# expression_gene("GSM847777", "447", 9.54).
# high_expression("GSM847777", "447").
# expression_gene("GSM847777", "448", 7.37).
# high_expression("GSM847777", "448").
# expression_gene("GSM847777", "449", 6.82).
# high_expression("GSM847777", "449").
# expression_gene("GSM847777", "450", 6.77).
# high_expression("GSM847777", "450").
# expression_gene("GSM847777", "451", 3.44).
# expression_gene("GSM847777", "452", 6.86).
# high_expression("GSM847777", "452").
# expression_gene("GSM847777", "453", 2.81).
# expression_gene("GSM847777", "454", 8.28).
# high_expression("GSM847777", "454").
# expression_gene("GSM847777", "455", 7.62).
# high_expression("GSM847777", "455").
# expression_gene("GSM847777", "456", 6.12).
# high_expression("GSM847777", "456").
# expression_gene("GSM847777", "457", 5.43).
# high_expression("GSM847777", "457").
# expression_gene("GSM847777", "458", 7.07).
# high_expression("GSM847777", "458").
# expression_gene("GSM847777", "459", 5.15).
# high_expression("GSM847777", "459").
# expression_gene("GSM847777", "460", 5.48).
# high_expression("GSM847777", "460").
# expression_gene("GSM847777", "461", 6.20).
# high_expression("GSM847777", "461").
# expression_gene("GSM847777", "462", 9.28).
# high_expression("GSM847777", "462").
# expression_gene("GSM847777", "463", 3.51).
# expression_gene("GSM847777", "464", 6.59).
# high_expression("GSM847777", "464").
# expression_gene("GSM847777", "465", 5.48).
# high_expression("GSM847777", "465").
# expression_gene("GSM847777", "466", 4.63).
# expression_gene("GSM847777", "467", 6.31).
# high_expression("GSM847777", "467").
# expression_gene("GSM847777", "468", 8.10).
# high_expression("GSM847777", "468").
# expression_gene("GSM847777", "469", 5.82).
# high_expression("GSM847777", "469").
# expression_gene("GSM847777", "470", 3.40).
# expression_gene("GSM847777", "471", 6.03).
# high_expression("GSM847777", "471").
# expression_gene("GSM847777", "472", 6.28).
# high_expression("GSM847777", "472").
# expression_gene("GSM847777", "473", 3.62).
# expression_gene("GSM847777", "474", 4.97).
# expression_gene("GSM847777", "475", 8.81).
# high_expression("GSM847777", "475").
# expression_gene("GSM847777", "476", 5.65).
# high_expression("GSM847777", "476").
# expression_gene("GSM847777", "477", 4.37).
# expression_gene("GSM847777", "478", 4.72).
# expression_gene("GSM847777", "479", 3.47).
# expression_gene("GSM847777", "480", 6.82).
# high_expression("GSM847777", "480").
# expression_gene("GSM847777", "481", 5.12).
# high_expression("GSM847777", "481").
# expression_gene("GSM847777", "482", 3.96).
# expression_gene("GSM847777", "483", 6.64).
# high_expression("GSM847777", "483").
# expression_gene("GSM847777", "484", 4.73).
# expression_gene("GSM847777", "485", 6.13).
# high_expression("GSM847777", "485").
# expression_gene("GSM847777", "486", 3.35).
# expression_gene("GSM847777", "487", 4.81).
# expression_gene("GSM847777", "488", 3.30).
# expression_gene("GSM847777", "489", 6.58).
# high_expression("GSM847777", "489").
# expression_gene("GSM847777", "490", 8.04).
# high_expression("GSM847777", "490").
# expression_gene("GSM847777", "491", 6.56).
# high_expression("GSM847777", "491").
# expression_gene("GSM847777", "492", 7.28).
# high_expression("GSM847777", "492").
# expression_gene("GSM847777", "493", 5.91).
# high_expression("GSM847777", "493").
# expression_gene("GSM847777", "494", 5.06).
# high_expression("GSM847777", "494").
# expression_gene("GSM847777", "495", 4.44).
# expression_gene("GSM847777", "496", 5.89).
# high_expression("GSM847777", "496").
# expression_gene("GSM847777", "497", 4.93).
# expression_gene("GSM847777", "498", 6.41).
# high_expression("GSM847777", "498").
# expression_gene("GSM847777", "499", 5.49).
# high_expression("GSM847777", "499").
# expression_gene("GSM847777", "500", 8.63).
# high_expression("GSM847777", "500").
# expression_gene("GSM847777", "501", 3.67).
# expression_gene("GSM847777", "502", 10.06).
# high_expression("GSM847777", "502").
# expression_gene("GSM847777", "503", 7.60).
# high_expression("GSM847777", "503").
# expression_gene("GSM847777", "504", 5.55).
# high_expression("GSM847777", "504").
# expression_gene("GSM847777", "505", 3.19).
# expression_gene("GSM847777", "506", 10.31).
# high_expression("GSM847777", "506").
# expression_gene("GSM847777", "507", 4.08).
# expression_gene("GSM847777", "508", 8.15).
# high_expression("GSM847777", "508").
# expression_gene("GSM847777", "509", 6.94).
# high_expression("GSM847777", "509").
# expression_gene("GSM847777", "510", 8.10).
# high_expression("GSM847777", "510").
# expression_gene("GSM847777", "511", 4.59).
# expression_gene("GSM847777", "512", 4.87).
# expression_gene("GSM847777", "513", 7.91).
# high_expression("GSM847777", "513").
# expression_gene("GSM847777", "514", 6.91).
# high_expression("GSM847777", "514").
# expression_gene("GSM847777", "515", 7.67).
# high_expression("GSM847777", "515").
# expression_gene("GSM847777", "516", 7.92).
# high_expression("GSM847777", "516").
# expression_gene("GSM847777", "517", 8.66).
# high_expression("GSM847777", "517").
# expression_gene("GSM847777", "518", 9.59).
# high_expression("GSM847777", "518").
# expression_gene("GSM847777", "519", 5.46).
# high_expression("GSM847777", "519").
# expression_gene("GSM847777", "520", 5.61).
# high_expression("GSM847777", "520").
# expression_gene("GSM847777", "521", 8.02).
# high_expression("GSM847777", "521").
# expression_gene("GSM847777", "522", 3.91).
# expression_gene("GSM847777", "523", 4.54).
# expression_gene("GSM847777", "524", 6.83).
# high_expression("GSM847777", "524").
# expression_gene("GSM847777", "525", 4.64).
# expression_gene("GSM847777", "526", 8.32).
# high_expression("GSM847777", "526").
# expression_gene("GSM847777", "527", 8.83).
# high_expression("GSM847777", "527").
# expression_gene("GSM847777", "528", 3.69).
# expression_gene("GSM847777", "529", 4.45).
# expression_gene("GSM847777", "530", 6.18).
# high_expression("GSM847777", "530").
# expression_gene("GSM847777", "531", 4.05).
# expression_gene("GSM847777", "532", 3.70).
# expression_gene("GSM847777", "533", 2.77).
# expression_gene("GSM847777", "534", 3.16).
# expression_gene("GSM847777", "535", 7.82).
# high_expression("GSM847777", "535").
# expression_gene("GSM847777", "536", 4.13).
# expression_gene("GSM847777", "537", 4.87).
# expression_gene("GSM847777", "538", 4.80).
# expression_gene("GSM847777", "539", 6.04).
# high_expression("GSM847777", "539").
# expression_gene("GSM847777", "540", 7.62).
# high_expression("GSM847777", "540").
# expression_gene("GSM847777", "541", 7.88).
# high_expression("GSM847777", "541").
# expression_gene("GSM847777", "542", 8.11).
# high_expression("GSM847777", "542").
# expression_gene("GSM847777", "543", 4.70).
# expression_gene("GSM847777", "544", 5.65).
# high_expression("GSM847777", "544").
# expression_gene("GSM847777", "545", 2.87).
# expression_gene("GSM847777", "546", 3.58).
# expression_gene("GSM847777", "547", 3.68).
# expression_gene("GSM847777", "548", 4.87).
# expression_gene("GSM847777", "549", 8.07).
# high_expression("GSM847777", "549").
# expression_gene("GSM847777", "550", 3.88).
# expression_gene("GSM847777", "551", 5.23).
# high_expression("GSM847777", "551").
# expression_gene("GSM847777", "552", 7.05).
# high_expression("GSM847777", "552").
# expression_gene("GSM847777", "553", 5.39).
# high_expression("GSM847777", "553").
# expression_gene("GSM847777", "554", 10.22).
# high_expression("GSM847777", "554").
# expression_gene("GSM847777", "555", 9.32).
# high_expression("GSM847777", "555").
# expression_gene("GSM847777", "556", 9.42).
# high_expression("GSM847777", "556").
# expression_gene("GSM847777", "557", 5.16).
# high_expression("GSM847777", "557").
# expression_gene("GSM847777", "558", 3.30).
# expression_gene("GSM847777", "559", 4.95).
# expression_gene("GSM847777", "560", 6.54).
# high_expression("GSM847777", "560").
# expression_gene("GSM847777", "561", 7.65).
# high_expression("GSM847777", "561").
# expression_gene("GSM847777", "562", 10.31).
# high_expression("GSM847777", "562").
# expression_gene("GSM847777", "563", 3.89).
# expression_gene("GSM847777", "564", 7.48).
# high_expression("GSM847777", "564").
# expression_gene("GSM847777", "565", 4.10).
# expression_gene("GSM847777", "566", 5.99).
# high_expression("GSM847777", "566").
# expression_gene("GSM847777", "567", 7.60).
# high_expression("GSM847777", "567").
# expression_gene("GSM847777", "568", 6.85).
# high_expression("GSM847777", "568").
# expression_gene("GSM847777", "569", 3.57).
# expression_gene("GSM847777", "570", 7.69).
# high_expression("GSM847777", "570").
# expression_gene("GSM847777", "571", 10.86).
# high_expression("GSM847777", "571").
# expression_gene("GSM847777", "572", 8.98).
# high_expression("GSM847777", "572").
# expression_gene("GSM847777", "573", 3.04).
# expression_gene("GSM847777", "574", 4.84).
# expression_gene("GSM847777", "575", 5.22).
# high_expression("GSM847777", "575").
# expression_gene("GSM847777", "576", 7.40).
# high_expression("GSM847777", "576").
# expression_gene("GSM847777", "577", 2.78).
# expression_gene("GSM847777", "578", 3.88).
# expression_gene("GSM847777", "579", 7.07).
# high_expression("GSM847777", "579").
# expression_gene("GSM847777", "580", 5.10).
# high_expression("GSM847777", "580").
# expression_gene("GSM847777", "581", 4.34).
# expression_gene("GSM847777", "582", 6.38).
# high_expression("GSM847777", "582").
# expression_gene("GSM847777", "583", 3.10).
# expression_gene("GSM847777", "584", 8.53).
# high_expression("GSM847777", "584").
# expression_gene("GSM847777", "585", 3.58).
# expression_gene("GSM847777", "586", 9.86).
# high_expression("GSM847777", "586").
# expression_gene("GSM847777", "587", 9.25).
# high_expression("GSM847777", "587").
# expression_gene("GSM847777", "588", 5.25).
# high_expression("GSM847777", "588").
# expression_gene("GSM847777", "589", 5.27).
# high_expression("GSM847777", "589").
# expression_gene("GSM847777", "590", 3.48).
# expression_gene("GSM847777", "591", 5.45).
# high_expression("GSM847777", "591").
# expression_gene("GSM847777", "592", 4.95).
# expression_gene("GSM847777", "593", 3.73).
# expression_gene("GSM847777", "594", 3.54).
# expression_gene("GSM847777", "595", 4.81).
# expression_gene("GSM847777", "596", 2.83).
# expression_gene("GSM847777", "597", 3.10).
# expression_gene("GSM847777", "598", 4.41).
# expression_gene("GSM847777", "599", 6.54).
# high_expression("GSM847777", "599").
# expression_gene("GSM847777", "600", 2.80).
# expression_gene("GSM847777", "601", 3.53).
# expression_gene("GSM847777", "602", 4.54).
# expression_gene("GSM847777", "603", 3.69).
# expression_gene("GSM847777", "604", 8.72).
# high_expression("GSM847777", "604").
# expression_gene("GSM847777", "605", 7.37).
# high_expression("GSM847777", "605").
# expression_gene("GSM847777", "606", 6.73).
# high_expression("GSM847777", "606").
# expression_gene("GSM847777", "607", 9.22).
# high_expression("GSM847777", "607").
# expression_gene("GSM847777", "608", 4.63).
# expression_gene("GSM847777", "609", 5.18).
# high_expression("GSM847777", "609").
# expression_gene("GSM847777", "610", 10.55).
# high_expression("GSM847777", "610").
# expression_gene("GSM847777", "611", 3.53).
# expression_gene("GSM847777", "612", 12.52).
# high_expression("GSM847777", "612").
# expression_gene("GSM847777", "613", 8.45).
# high_expression("GSM847777", "613").
# expression_gene("GSM847777", "614", 8.44).
# high_expression("GSM847777", "614").
# expression_gene("GSM847777", "615", 5.29).
# high_expression("GSM847777", "615").
# expression_gene("GSM847777", "616", 9.89).
# high_expression("GSM847777", "616").
# expression_gene("GSM847777", "617", 6.95).
# high_expression("GSM847777", "617").
# expression_gene("GSM847777", "618", 3.34).
# expression_gene("GSM847777", "619", 3.57).
# expression_gene("GSM847777", "620", 8.44).
# high_expression("GSM847777", "620").
# expression_gene("GSM847777", "621", 7.56).
# high_expression("GSM847777", "621").
# expression_gene("GSM847777", "622", 5.46).
# high_expression("GSM847777", "622").
# expression_gene("GSM847777", "623", 6.71).
# high_expression("GSM847777", "623").
# expression_gene("GSM847777", "624", 3.29).
# expression_gene("GSM847777", "625", 6.20).
# high_expression("GSM847777", "625").
# expression_gene("GSM847777", "626", 4.68).
# expression_gene("GSM847777", "627", 3.35).
# expression_gene("GSM847777", "628", 4.00).
# expression_gene("GSM847777", "629", 5.38).
# high_expression("GSM847777", "629").
# expression_gene("GSM847777", "630", 2.81).
# expression_gene("GSM847777", "631", 2.75).
# expression_gene("GSM847777", "632", 2.77).
# expression_gene("GSM847777", "633", 5.66).
# high_expression("GSM847777", "633").
# expression_gene("GSM847777", "634", 4.70).
# expression_gene("GSM847777", "635", 4.40).
# expression_gene("GSM847777", "636", 8.50).
# high_expression("GSM847777", "636").
# expression_gene("GSM847777", "637", 7.27).
# high_expression("GSM847777", "637").
# expression_gene("GSM847777", "638", 6.99).
# high_expression("GSM847777", "638").
# expression_gene("GSM847777", "639", 4.28).
# expression_gene("GSM847777", "640", 4.19).
# expression_gene("GSM847777", "641", 2.87).
# expression_gene("GSM847777", "642", 6.10).
# high_expression("GSM847777", "642").
# expression_gene("GSM847777", "643", 9.49).
# high_expression("GSM847777", "643").
# expression_gene("GSM847777", "644", 8.56).
# high_expression("GSM847777", "644").
# expression_gene("GSM847777", "645", 3.11).
# expression_gene("GSM847777", "646", 9.44).
# high_expression("GSM847777", "646").
# expression_gene("GSM847777", "647", 2.96).
# expression_gene("GSM847777", "648", 6.87).
# high_expression("GSM847777", "648").
# expression_gene("GSM847777", "649", 8.47).
# high_expression("GSM847777", "649").
# expression_gene("GSM847777", "650", 9.30).
# high_expression("GSM847777", "650").
# expression_gene("GSM847777", "651", 6.62).
# high_expression("GSM847777", "651").
# expression_gene("GSM847777", "652", 4.16).
# expression_gene("GSM847777", "653", 6.85).
# high_expression("GSM847777", "653").
# expression_gene("GSM847777", "654", 10.89).
# high_expression("GSM847777", "654").
# expression_gene("GSM847777", "655", 4.99).
# expression_gene("GSM847777", "656", 9.23).
# high_expression("GSM847777", "656").
# expression_gene("GSM847777", "657", 3.73).
# expression_gene("GSM847777", "658", 8.25).
# high_expression("GSM847777", "658").
# expression_gene("GSM847777", "659", 7.14).
# high_expression("GSM847777", "659").
# expression_gene("GSM847777", "660", 7.14).
# high_expression("GSM847777", "660").
# expression_gene("GSM847777", "661", 10.27).
# high_expression("GSM847777", "661").
# expression_gene("GSM847777", "662", 8.33).
# high_expression("GSM847777", "662").
# expression_gene("GSM847777", "663", 5.15).
# high_expression("GSM847777", "663").
# expression_gene("GSM847777", "664", 4.18).
# expression_gene("GSM847777", "665", 3.62).
# expression_gene("GSM847777", "666", 3.04).
# expression_gene("GSM847777", "667", 3.97).
# expression_gene("GSM847777", "668", 6.78).
# high_expression("GSM847777", "668").
# expression_gene("GSM847777", "669", 5.35).
# high_expression("GSM847777", "669").
# expression_gene("GSM847777", "670", 2.70).
# expression_gene("GSM847777", "671", 7.12).
# high_expression("GSM847777", "671").
# expression_gene("GSM847777", "672", 3.68).
# expression_gene("GSM847777", "673", 3.59).
# expression_gene("GSM847777", "674", 7.62).
# high_expression("GSM847777", "674").
# expression_gene("GSM847777", "675", 6.04).
# high_expression("GSM847777", "675").
# expression_gene("GSM847777", "676", 5.76).
# high_expression("GSM847777", "676").
# expression_gene("GSM847777", "677", 3.91).
# expression_gene("GSM847777", "678", 8.29).
# high_expression("GSM847777", "678").
# expression_gene("GSM847777", "679", 4.73).
# expression_gene("GSM847777", "680", 5.77).
# high_expression("GSM847777", "680").
# expression_gene("GSM847777", "681", 8.34).
# high_expression("GSM847777", "681").
# expression_gene("GSM847777", "682", 10.63).
# high_expression("GSM847777", "682").
# expression_gene("GSM847777", "683", 5.18).
# high_expression("GSM847777", "683").
# expression_gene("GSM847777", "684", 3.38).
# expression_gene("GSM847777", "685", 4.52).
# expression_gene("GSM847777", "686", 5.43).
# high_expression("GSM847777", "686").
# expression_gene("GSM847777", "687", 3.54).
# expression_gene("GSM847777", "688", 5.89).
# high_expression("GSM847777", "688").
# expression_gene("GSM847777", "689", 4.43).
# expression_gene("GSM847777", "690", 7.51).
# high_expression("GSM847777", "690").
# expression_gene("GSM847777", "691", 7.60).
# high_expression("GSM847777", "691").
# expression_gene("GSM847777", "692", 6.34).
# high_expression("GSM847777", "692").
# expression_gene("GSM847777", "693", 6.99).
# high_expression("GSM847777", "693").
# expression_gene("GSM847777", "694", 7.07).
# high_expression("GSM847777", "694").
# expression_gene("GSM847777", "695", 8.07).
# high_expression("GSM847777", "695").
# expression_gene("GSM847777", "696", 8.87).
# high_expression("GSM847777", "696").
# expression_gene("GSM847777", "697", 5.00).
# high_expression("GSM847777", "697").
# expression_gene("GSM847777", "698", 4.76).
# expression_gene("GSM847777", "699", 5.44).
# high_expression("GSM847777", "699").
# expression_gene("GSM847777", "700", 5.18).
# high_expression("GSM847777", "700").
# expression_gene("GSM847777", "701", 9.79).
# high_expression("GSM847777", "701").
# expression_gene("GSM847777", "702", 12.22).
# high_expression("GSM847777", "702").
# expression_gene("GSM847777", "703", 6.08).
# high_expression("GSM847777", "703").
# expression_gene("GSM847777", "704", 10.81).
# high_expression("GSM847777", "704").
# expression_gene("GSM847777", "705", 9.58).
# high_expression("GSM847777", "705").
# expression_gene("GSM847777", "706", 8.92).
# high_expression("GSM847777", "706").
# expression_gene("GSM847777", "707", 4.17).
# expression_gene("GSM847777", "708", 9.16).
# high_expression("GSM847777", "708").
# expression_gene("GSM847777", "709", 9.87).
# high_expression("GSM847777", "709").
# expression_gene("GSM847777", "710", 3.74).
# expression_gene("GSM847777", "711", 6.46).
# high_expression("GSM847777", "711").
# expression_gene("GSM847777", "712", 7.55).
# high_expression("GSM847777", "712").
# expression_gene("GSM847777", "713", 8.64).
# high_expression("GSM847777", "713").
# expression_gene("GSM847777", "714", 4.13).
# expression_gene("GSM847777", "715", 9.09).
# high_expression("GSM847777", "715").
# expression_gene("GSM847777", "716", 8.79).
# high_expression("GSM847777", "716").
# expression_gene("GSM847777", "717", 6.54).
# high_expression("GSM847777", "717").
# expression_gene("GSM847777", "718", 5.47).
# high_expression("GSM847777", "718").
# expression_gene("GSM847777", "719", 5.65).
# high_expression("GSM847777", "719").
# expression_gene("GSM847777", "720", 5.50).
# high_expression("GSM847777", "720").
# expression_gene("GSM847777", "721", 2.89).
# expression_gene("GSM847777", "722", 5.44).
# high_expression("GSM847777", "722").
# expression_gene("GSM847777", "723", 3.39).
# expression_gene("GSM847777", "724", 6.35).
# high_expression("GSM847777", "724").
# expression_gene("GSM847777", "725", 4.48).
# expression_gene("GSM847777", "726", 6.84).
# high_expression("GSM847777", "726").
# expression_gene("GSM847777", "727", 8.93).
# high_expression("GSM847777", "727").
# expression_gene("GSM847777", "728", 8.48).
# high_expression("GSM847777", "728").
# expression_gene("GSM847777", "729", 7.87).
# high_expression("GSM847777", "729").
# expression_gene("GSM847777", "730", 3.63).
# expression_gene("GSM847777", "731", 9.58).
# high_expression("GSM847777", "731").
# expression_gene("GSM847777", "732", 7.34).
# high_expression("GSM847777", "732").
# expression_gene("GSM847777", "733", 6.71).
# high_expression("GSM847777", "733").
# expression_gene("GSM847777", "734", 8.47).
# high_expression("GSM847777", "734").
# expression_gene("GSM847777", "735", 7.17).
# high_expression("GSM847777", "735").
# expression_gene("GSM847777", "736", 4.32).
# expression_gene("GSM847777", "737", 6.08).
# high_expression("GSM847777", "737").
# expression_gene("GSM847777", "738", 3.71).
# expression_gene("GSM847777", "739", 4.85).
# expression_gene("GSM847777", "740", 6.72).
# high_expression("GSM847777", "740").
# expression_gene("GSM847777", "741", 4.21).
# expression_gene("GSM847777", "742", 4.17).
# expression_gene("GSM847777", "743", 5.26).
# high_expression("GSM847777", "743").
# expression_gene("GSM847777", "744", 8.59).
# high_expression("GSM847777", "744").
# expression_gene("GSM847777", "745", 7.22).
# high_expression("GSM847777", "745").
# expression_gene("GSM847777", "746", 7.31).
# high_expression("GSM847777", "746").
# expression_gene("GSM847777", "747", 5.05).
# high_expression("GSM847777", "747").
# expression_gene("GSM847777", "748", 5.93).
# high_expression("GSM847777", "748").
# expression_gene("GSM847777", "749", 8.24).
# high_expression("GSM847777", "749").
# expression_gene("GSM847777", "750", 9.41).
# high_expression("GSM847777", "750").
# expression_gene("GSM847777", "751", 10.00).
# high_expression("GSM847777", "751").
# expression_gene("GSM847777", "752", 3.97).
# expression_gene("GSM847777", "753", 5.39).
# high_expression("GSM847777", "753").
# expression_gene("GSM847777", "754", 9.79).
# high_expression("GSM847777", "754").
# expression_gene("GSM847777", "755", 11.68).
# high_expression("GSM847777", "755").
# expression_gene("GSM847777", "756", 8.82).
# high_expression("GSM847777", "756").
# expression_gene("GSM847777", "757", 3.91).
# expression_gene("GSM847777", "758", 4.76).
# expression_gene("GSM847777", "759", 7.17).
# high_expression("GSM847777", "759").
# expression_gene("GSM847777", "760", 7.61).
# high_expression("GSM847777", "760").
# expression_gene("GSM847777", "761", 7.20).
# high_expression("GSM847777", "761").
# expression_gene("GSM847777", "762", 6.25).
# high_expression("GSM847777", "762").
# expression_gene("GSM847777", "763", 5.06).
# high_expression("GSM847777", "763").
# expression_gene("GSM847777", "764", 6.63).
# ...
# expression_gene("GSM847777", "35036", 2.97).
# expression_gene("GSM847777", "35037", 3.33).
# expression_gene("GSM847777", "35038", 5.46).
# high_expression("GSM847777", "35038").
# expression_gene("GSM847777", "35039", 3.60).
# expression_gene("GSM847777", "35040", 3.59).
# expression_gene("GSM847777", "35041", 4.93).
# expression_gene("GSM847777", "35042", 5.95).
# high_expression("GSM847777", "35042").
# expression_gene("GSM847777", "35043", 3.40).
# expression_gene("GSM847777", "35044", 2.75).
# expression_gene("GSM847777", "35045", 4.77).
# expression_gene("GSM847777", "35046", 3.50).
# expression_gene("GSM847777", "35047", 3.10).
# expression_gene("GSM847777", "35048", 3.10).
# expression_gene("GSM847777", "35049", 4.18).
# expression_gene("GSM847777", "35050", 3.03).
# expression_gene("GSM847777", "35051", 3.58).
# expression_gene("GSM847777", "35052", 3.01).
# expression_gene("GSM847777", "35053", 7.57).
# high_expression("GSM847777", "35053").
# expression_gene("GSM847777", "35054", 5.82).
# high_expression("GSM847777", "35054").
# expression_gene("GSM847777", "35055", 5.08).
# high_expression("GSM847777", "35055").
# expression_gene("GSM847777", "35056", 6.28).
# high_expression("GSM847777", "35056").
# expression_gene("GSM847777", "35057", 4.19).
# expression_gene("GSM847777", "35058", 2.71).
# expression_gene("GSM847777", "35059", 4.38).
# expression_gene("GSM847777", "35060", 3.67).
# expression_gene("GSM847777", "35061", 5.49).
# high_expression("GSM847777", "35061").
# expression_gene("GSM847777", "35062", 4.73).
# expression_gene("GSM847777", "35063", 3.51).
# expression_gene("GSM847777", "35064", 3.56).
# expression_gene("GSM847777", "35065", 5.84).
# high_expression("GSM847777", "35065").
# expression_gene("GSM847777", "35066", 12.23).
# high_expression("GSM847777", "35066").
# expression_gene("GSM847777", "35067", 5.53).
# high_expression("GSM847777", "35067").
# expression_gene("GSM847777", "35068", 7.35).
# high_expression("GSM847777", "35068").
# expression_gene("GSM847777", "35069", 3.13).
# expression_gene("GSM847777", "35070", 3.36).
# expression_gene("GSM847777", "35071", 2.77).
# expression_gene("GSM847777", "35072", 2.85).
# expression_gene("GSM847777", "35073", 4.08).
# expression_gene("GSM847777", "35074", 3.66).
# expression_gene("GSM847777", "35075", 3.39).
# expression_gene("GSM847777", "35076", 3.60).
# expression_gene("GSM847777", "35077", 10.26).
# high_expression("GSM847777", "35077").
# expression_gene("GSM847777", "35078", 3.75).
# expression_gene("GSM847777", "35079", 3.82).
# expression_gene("GSM847777", "35080", 3.10).
# expression_gene("GSM847777", "35081", 3.27).
# expression_gene("GSM847777", "35082", 4.91).
# expression_gene("GSM847777", "35083", 6.12).
# high_expression("GSM847777", "35083").
# expression_gene("GSM847777", "35084", 2.97).
# expression_gene("GSM847777", "35085", 5.65).
# high_expression("GSM847777", "35085").
# expression_gene("GSM847777", "35086", 4.10).
# expression_gene("GSM847777", "35087", 3.38).
# expression_gene("GSM847777", "35088", 6.27).
# high_expression("GSM847777", "35088").
# expression_gene("GSM847777", "35089", 4.15).
# expression_gene("GSM847777", "35090", 3.60).
# expression_gene("GSM847777", "35091", 4.12).
# expression_gene("GSM847777", "35092", 3.45).
# expression_gene("GSM847777", "35093", 4.84).
# expression_gene("GSM847777", "35094", 8.53).
# high_expression("GSM847777", "35094").
# expression_gene("GSM847777", "35095", 5.32).
# high_expression("GSM847777", "35095").
# expression_gene("GSM847777", "35096", 3.52).
# expression_gene("GSM847777", "35097", 3.19).
# expression_gene("GSM847777", "35098", 7.47).
# high_expression("GSM847777", "35098").
# expression_gene("GSM847777", "35099", 3.32).
# expression_gene("GSM847777", "35100", 4.86).
# expression_gene("GSM847777", "35101", 2.91).
# expression_gene("GSM847777", "35102", 3.37).
# expression_gene("GSM847777", "35103", 9.04).
# high_expression("GSM847777", "35103").
# expression_gene("GSM847777", "35104", 3.20).
# expression_gene("GSM847777", "35105", 3.30).
# expression_gene("GSM847777", "35106", 5.05).
# high_expression("GSM847777", "35106").
# expression_gene("GSM847777", "35107", 3.78).
# expression_gene("GSM847777", "35108", 4.00).
# expression_gene("GSM847777", "35109", 3.18).
# expression_gene("GSM847777", "35110", 3.29).
# expression_gene("GSM847777", "35111", 3.24).
# expression_gene("GSM847777", "35112", 7.34).
# high_expression("GSM847777", "35112").
# expression_gene("GSM847777", "35113", 2.86).
# expression_gene("GSM847777", "35114", 3.18).
# expression_gene("GSM847777", "35115", 5.51).
# high_expression("GSM847777", "35115").
# expression_gene("GSM847777", "35116", 5.64).
# high_expression("GSM847777", "35116").
# expression_gene("GSM847777", "35117", 3.34).
# expression_gene("GSM847777", "35118", 3.37).
# expression_gene("GSM847777", "35119", 5.25).
# high_expression("GSM847777", "35119").
# expression_gene("GSM847777", "35120", 4.74).
# expression_gene("GSM847777", "35121", 5.99).
# high_expression("GSM847777", "35121").
# expression_gene("GSM847777", "35122", 3.59).
# expression_gene("GSM847777", "35123", 4.15).
# expression_gene("GSM847777", "35124", 4.48).
# expression_gene("GSM847777", "35125", 3.74).
# expression_gene("GSM847777", "35126", 7.09).
# high_expression("GSM847777", "35126").
# expression_gene("GSM847777", "35127", 9.21).
# high_expression("GSM847777", "35127").
# expression_gene("GSM847777", "35128", 9.17).
# high_expression("GSM847777", "35128").
# expression_gene("GSM847777", "35129", 7.86).
# high_expression("GSM847777", "35129").
# expression_gene("GSM847777", "35130", 5.20).
# high_expression("GSM847777", "35130").
# expression_gene("GSM847777", "35131", 9.23).
# high_expression("GSM847777", "35131").
# expression_gene("GSM847777", "35132", 6.49).
# high_expression("GSM847777", "35132").
# expression_gene("GSM847777", "35133", 8.70).
# high_expression("GSM847777", "35133").
# expression_gene("GSM847777", "35134", 6.90).
# high_expression("GSM847777", "35134").
# expression_gene("GSM847777", "35135", 9.15).
# high_expression("GSM847777", "35135").
# expression_gene("GSM847777", "35136", 8.14).
# high_expression("GSM847777", "35136").
# expression_gene("GSM847777", "35137", 10.50).
# high_expression("GSM847777", "35137").
# expression_gene("GSM847777", "35138", 7.47).
# high_expression("GSM847777", "35138").
# expression_gene("GSM847777", "35139", 7.72).
# high_expression("GSM847777", "35139").
# expression_gene("GSM847777", "35140", 4.66).
# expression_gene("GSM847777", "35141", 7.88).
# high_expression("GSM847777", "35141").
# expression_gene("GSM847777", "35142", 4.56).
# expression_gene("GSM847777", "35143", 6.00).
# high_expression("GSM847777", "35143").
# expression_gene("GSM847777", "35144", 6.48).
# high_expression("GSM847777", "35144").
# expression_gene("GSM847777", "35145", 6.93).
# high_expression("GSM847777", "35145").
# expression_gene("GSM847777", "35146", 6.97).
# high_expression("GSM847777", "35146").
# expression_gene("GSM847777", "35147", 6.94).
# high_expression("GSM847777", "35147").
# expression_gene("GSM847777", "35148", 9.47).
# high_expression("GSM847777", "35148").
# expression_gene("GSM847777", "35149", 4.99).
# expression_gene("GSM847777", "35150", 7.96).
# high_expression("GSM847777", "35150").
# expression_gene("GSM847777", "35151", 5.11).
# high_expression("GSM847777", "35151").
# expression_gene("GSM847777", "35152", 4.32).
# expression_gene("GSM847777", "35153", 6.59).
# high_expression("GSM847777", "35153").
# expression_gene("GSM847777", "35154", 3.63).
# expression_gene("GSM847777", "35155", 6.47).
# high_expression("GSM847777", "35155").
# expression_gene("GSM847777", "35156", 7.08).
# high_expression("GSM847777", "35156").
# expression_gene("GSM847777", "35157", 3.52).
# expression_gene("GSM847777", "35158", 4.89).
# expression_gene("GSM847777", "35159", 4.99).
# expression_gene("GSM847777", "35160", 2.91).
# expression_gene("GSM847777", "35161", 3.66).
# expression_gene("GSM847777", "35162", 3.35).
# expression_gene("GSM847777", "35163", 3.27).
# expression_gene("GSM847777", "35164", 3.17).
# expression_gene("GSM847777", "35165", 3.94).
# expression_gene("GSM847777", "35166", 5.42).
# high_expression("GSM847777", "35166").
# expression_gene("GSM847777", "35167", 4.22).
# expression_gene("GSM847777", "35168", 4.39).
# expression_gene("GSM847777", "35169", 5.22).
# high_expression("GSM847777", "35169").
# expression_gene("GSM847777", "35170", 7.48).
# high_expression("GSM847777", "35170").
# expression_gene("GSM847777", "35171", 7.88).
# high_expression("GSM847777", "35171").
# expression_gene("GSM847777", "35172", 9.45).
# high_expression("GSM847777", "35172").
# expression_gene("GSM847777", "35173", 6.35).
# high_expression("GSM847777", "35173").
# expression_gene("GSM847777", "35174", 4.31).
# expression_gene("GSM847777", "35175", 3.47).
# expression_gene("GSM847777", "35176", 4.77).
# expression_gene("GSM847777", "35177", 4.76).
# expression_gene("GSM847777", "35178", 5.67).
# high_expression("GSM847777", "35178").
# expression_gene("GSM847777", "35179", 9.27).
# high_expression("GSM847777", "35179").
# expression_gene("GSM847777", "35180", 3.69).
# expression_gene("GSM847777", "35181", 9.26).
# high_expression("GSM847777", "35181").
# expression_gene("GSM847777", "35182", 4.52).
# expression_gene("GSM847777", "35183", 5.25).
# high_expression("GSM847777", "35183").
# expression_gene("GSM847777", "35184", 2.92).
# expression_gene("GSM847777", "35185", 9.17).
# high_expression("GSM847777", "35185").
# expression_gene("GSM847777", "35186", 9.74).
# high_expression("GSM847777", "35186").
# expression_gene("GSM847777", "35187", 6.32).
# high_expression("GSM847777", "35187").
# expression_gene("GSM847777", "35188", 8.11).
# high_expression("GSM847777", "35188").
# expression_gene("GSM847777", "35189", 5.09).
# high_expression("GSM847777", "35189").
# expression_gene("GSM847777", "35190", 7.51).
# high_expression("GSM847777", "35190").
# expression_gene("GSM847777", "35191", 9.35).
# high_expression("GSM847777", "35191").
# expression_gene("GSM847777", "35192", 7.94).
# high_expression("GSM847777", "35192").
# expression_gene("GSM847777", "35193", 6.97).
# high_expression("GSM847777", "35193").
# expression_gene("GSM847777", "35194", 6.46).
# high_expression("GSM847777", "35194").
# expression_gene("GSM847777", "35195", 3.63).
# expression_gene("GSM847777", "35196", 7.15).
# high_expression("GSM847777", "35196").
# expression_gene("GSM847777", "35197", 8.29).
# high_expression("GSM847777", "35197").
# expression_gene("GSM847777", "35198", 10.77).
# high_expression("GSM847777", "35198").
# expression_gene("GSM847777", "35199", 6.07).
# high_expression("GSM847777", "35199").
# expression_gene("GSM847777", "35200", 5.86).
# high_expression("GSM847777", "35200").
# expression_gene("GSM847777", "35201", 8.08).
# high_expression("GSM847777", "35201").
# expression_gene("GSM847777", "35202", 3.70).
# expression_gene("GSM847777", "35203", 7.54).
# high_expression("GSM847777", "35203").
# expression_gene("GSM847777", "35204", 3.63).
# expression_gene("GSM847777", "35205", 9.27).
# high_expression("GSM847777", "35205").
# expression_gene("GSM847777", "35206", 4.98).
# expression_gene("GSM847777", "35207", 3.01).
# expression_gene("GSM847777", "35208", 5.86).
# high_expression("GSM847777", "35208").
# expression_gene("GSM847777", "35209", 6.85).
# high_expression("GSM847777", "35209").
# expression_gene("GSM847777", "35210", 7.80).
# high_expression("GSM847777", "35210").
# expression_gene("GSM847777", "35211", 10.33).
# high_expression("GSM847777", "35211").
# expression_gene("GSM847777", "35212", 4.67).
# expression_gene("GSM847777", "35213", 9.16).
# high_expression("GSM847777", "35213").
# expression_gene("GSM847777", "35214", 7.22).
# high_expression("GSM847777", "35214").
# expression_gene("GSM847777", "35215", 3.23).
# expression_gene("GSM847777", "35216", 3.87).
# expression_gene("GSM847777", "35217", 4.30).
# expression_gene("GSM847777", "35218", 4.79).
# expression_gene("GSM847777", "35219", 7.31).
# high_expression("GSM847777", "35219").
# expression_gene("GSM847777", "35220", 3.97).
# expression_gene("GSM847777", "35221", 7.76).
# high_expression("GSM847777", "35221").
# expression_gene("GSM847777", "35222", 4.14).
# expression_gene("GSM847777", "35223", 5.24).
# high_expression("GSM847777", "35223").
# expression_gene("GSM847777", "35224", 7.84).
# high_expression("GSM847777", "35224").
# expression_gene("GSM847777", "35225", 6.93).
# high_expression("GSM847777", "35225").
# expression_gene("GSM847777", "35226", 5.19).
# high_expression("GSM847777", "35226").
# expression_gene("GSM847777", "35227", 5.45).
# high_expression("GSM847777", "35227").
# expression_gene("GSM847777", "35228", 7.15).
# high_expression("GSM847777", "35228").
# expression_gene("GSM847777", "35229", 7.08).
# high_expression("GSM847777", "35229").
# expression_gene("GSM847777", "35230", 4.10).
# expression_gene("GSM847777", "35231", 6.01).
# high_expression("GSM847777", "35231").
# expression_gene("GSM847777", "35232", 8.23).
# high_expression("GSM847777", "35232").
# expression_gene("GSM847777", "35233", 7.43).
# high_expression("GSM847777", "35233").
# expression_gene("GSM847777", "35234", 4.11).
# expression_gene("GSM847777", "35235", 3.61).
# expression_gene("GSM847777", "35236", 7.27).
# high_expression("GSM847777", "35236").
# expression_gene("GSM847777", "35237", 5.16).
# high_expression("GSM847777", "35237").
# expression_gene("GSM847777", "35238", 5.02).
# high_expression("GSM847777", "35238").
# expression_gene("GSM847777", "35239", 6.77).
# high_expression("GSM847777", "35239").
# expression_gene("GSM847777", "35240", 3.46).
# expression_gene("GSM847777", "35241", 3.42).
# expression_gene("GSM847777", "35242", 2.98).
# expression_gene("GSM847777", "35243", 5.42).
# high_expression("GSM847777", "35243").
# expression_gene("GSM847777", "35244", 2.91).
# expression_gene("GSM847777", "35245", 5.46).
# high_expression("GSM847777", "35245").
# expression_gene("GSM847777", "35246", 8.75).
# high_expression("GSM847777", "35246").
# expression_gene("GSM847777", "35247", 7.87).
# high_expression("GSM847777", "35247").
# expression_gene("GSM847777", "35248", 9.10).
# high_expression("GSM847777", "35248").
# expression_gene("GSM847777", "35249", 5.42).
# high_expression("GSM847777", "35249").
# expression_gene("GSM847777", "35250", 7.89).
# high_expression("GSM847777", "35250").
# expression_gene("GSM847777", "35251", 9.61).
# high_expression("GSM847777", "35251").
# expression_gene("GSM847777", "35252", 3.99).
# expression_gene("GSM847777", "35253", 3.53).
# expression_gene("GSM847777", "35254", 5.24).
# high_expression("GSM847777", "35254").
# expression_gene("GSM847777", "35255", 6.64).
# high_expression("GSM847777", "35255").
# expression_gene("GSM847777", "35256", 3.91).
# expression_gene("GSM847777", "35257", 7.33).
# high_expression("GSM847777", "35257").
# expression_gene("GSM847777", "35258", 3.01).
# expression_gene("GSM847777", "35259", 9.50).
# high_expression("GSM847777", "35259").
# expression_gene("GSM847777", "35260", 8.52).
# high_expression("GSM847777", "35260").
# expression_gene("GSM847777", "35261", 5.27).
# high_expression("GSM847777", "35261").
# expression_gene("GSM847777", "35262", 5.09).
# high_expression("GSM847777", "35262").
# expression_gene("GSM847777", "35263", 3.10).
# expression_gene("GSM847777", "35264", 4.03).
# expression_gene("GSM847777", "35265", 3.34).
# expression_gene("GSM847777", "35266", 4.29).
# expression_gene("GSM847777", "35267", 3.79).
# expression_gene("GSM847777", "35268", 3.43).
# expression_gene("GSM847777", "35269", 2.80).
# expression_gene("GSM847777", "35270", 3.12).
# expression_gene("GSM847777", "35271", 5.79).
# high_expression("GSM847777", "35271").
# expression_gene("GSM847777", "35272", 3.34).
# expression_gene("GSM847777", "35273", 8.98).
# high_expression("GSM847777", "35273").
# expression_gene("GSM847777", "35274", 5.07).
# high_expression("GSM847777", "35274").
# expression_gene("GSM847777", "35275", 7.20).
# high_expression("GSM847777", "35275").
# expression_gene("GSM847777", "35276", 4.74).
# expression_gene("GSM847777", "35277", 7.87).
# high_expression("GSM847777", "35277").
# expression_gene("GSM847777", "35278", 5.12).
# high_expression("GSM847777", "35278").
# expression_gene("GSM847777", "35279", 3.06).
# expression_gene("GSM847777", "35280", 6.08).
# high_expression("GSM847777", "35280").
# expression_gene("GSM847777", "35281", 7.74).
# high_expression("GSM847777", "35281").
# expression_gene("GSM847777", "35282", 3.71).

# %%
with open(" GSM_table_(Metadata)+into_FOL_predicate_format.txt", "w") as f:
    for predicate in all_predicates: 
        f.write(predicate + "\n")    

with open(" GSM_table_(expression_predicates)+into_FOL_predicate_format.txt", "w") as f:
    for predicate in expression_predicates:
        f.write(predicate + "\n")
